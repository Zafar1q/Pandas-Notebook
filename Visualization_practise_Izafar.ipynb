# %% [markdown]
# # Solution Lecture 08 – Fall 2023
#
# Data Science, Fall 2023
#
# Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# In this lecture, we will demonstrate visualization techniques on the World Bank dataset. This dataset includes information about countries and development statistics from around the world.
#
# Load DataFrame and visualize

# %%
# read data frame
wb = pd.read_csv('C:\\Users\\zafar\\Downloads\\KM_notebook\\world_bank.csv')
wb.drop(columns= 'Unnamed: 0', inplace=True)
wb.head()
# Out:
#   Continent   Country  \
# 0    Africa   Algeria
# 1    Africa    Angola
# 2    Africa     Benin
# 3    Africa  Botswana
# 4    Africa   Burundi
#
#    Primary completion rate: Male: % of relevant age group: 2015  \
# 0                                              106.0
# 1                                                NaN
# 2                                               83.0
# 3                                               98.0
# 4                                               58.0
#
#    Primary completion rate: Female: % of relevant age group: 2015  \
# 0                                              105.0
# 1                                                NaN
# 2                                               73.0
# 3                                              101.0
# 4                                               66.0
#
#    Lower secondary completion rate: Male: % of relevant age group: 2015  \
# 0                                               68.0
# 1                                                NaN
# 2                                               50.0
# 3                                               86.0
# 4                                               35.0
#
#    Lower secondary completion rate: Female: % of relevant age group: 2015  \
# 0                                               85.0
# 1                                                NaN
# 2                                               37.0
# 3                                               87.0
# 4                                               30.0
#
#    Youth literacy rate: Male: % of ages 15-24: 2005-14  \
# 0                                               96.0
# 1                                               79.0
# 2                                               55.0
# 3                                               96.0
# 4                                               90.0
#
#    Youth literacy rate: Female: % of ages 15-24: 2005-14  \
# 0                                               92.0
# 1                                               67.0
# 2                                               31.0
# 3                                               99.0
# 4                                               88.0
#
#    Adult literacy rate: Male: % ages 15 and older: 2005-14  \
# 0                                               83.0
# 1                                               82.0
# 2                                               41.0
# 3                                               87.0
# 4                                               89.0
#
#    Adult literacy rate: Female: % ages 15 and older: 2005-14  ...  \
# 0                                               68.0          ...
# 1                                               60.0          ...
# 2                                               18.0          ...
# 3                                               89.0          ...
# 4                                               85.0          ...
#
#    Access to improved sanitation facilities: % of population: 1990  \
# 0                                               80.0
# 1                                               22.0
# 2                                                7.0
# 3                                               39.0
# 4                                               42.0
#
#    Access to improved sanitation facilities: % of population: 2015  \
# 0                                               88.0
# 1                                               52.0
# 2                                               20.0
# 3                                               63.0
# 4                                               48.0
#
#    Child immunization rate: Measles: % of children ages 12-23 months: 2015  \
# 0                                               95.0
# 1                                               55.0
# 2                                               75.0
# 3                                               97.0
# 4                                               93.0
#
#    Child immunization rate: DTP3: % of children ages 12-23 months: 2015  \
# 0                                               95.0
# 1                                               64.0
# 2                                               79.0
# 3                                               95.0
# 4                                               94.0
#
#    Children with acute respiratory infection taken to health provider: % of children under age 5 with ARI: 2009-2016  \
# 0                                               66.0
# 1                                                NaN
# 2                                               23.0
# 3                                                NaN
# 4                                               55.0
#
#    Children with diarrhea who received oral rehydration and continuous feeding: % of children under age 5 with diarrhea: 2009-2016  \
# 0                                               42.0
# 1                                                NaN
# 2                                               33.0
# 3                                                NaN
# 4                                               43.0
#
#    Children sleeping under treated bed nets: % of children under age 5: 2009-2016  \
# 0                                                NaN
# 1                                               25.9
# 2                                               72.7
# 3                                                NaN
# 4                                               53.8
#
#    Children with fever receiving antimalarial drugs: % of children under age 5 with fever: 2009-2016  \
# 0                                                NaN
# 1                                               28.3
# 2                                               25.9
# 3                                                NaN
# 4                                               25.4
#
#    Tuberculosis: Treatment success rate: % of new cases: 2014  \
# 0                                               88.0
# 1                                               34.0
# 2                                               89.0
# 3                                               77.0
# 4                                               91.0
#
#    Tuberculosis: Cases detection rate: % of new estimated cases: 2015
# 0                                               80.0
# 1                                               64.0
# 2                                               61.0
# 3                                               62.0
# 4                                               51.0
#
# [5 rows x 47 columns]

# %%
wb.shape
# Out:
# (166, 47)

# %% [markdown]
# ## Bar Plots

# %% [markdown]
# We often use bar plots to display **distributions** of a **categorical variable**.
#
# In the examples below, we plot the distribution of the `"Continent"` column. The cell below uses `.value_counts()` to determine the number of countries corresponding to each continent in the dataset.

# %%
wb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 47 columns):
#  #   Column                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                           --------------  -----
#  0   Continent                                                                                                                        166 non-null    object
#  1   Country                                                                                                                          166 non-null    object
#  2   Primary completion rate: Male: % of relevant age group: 2015                                                                     136 non-null    float64
#  3   Primary completion rate: Female: % of relevant age group: 2015                                                                   136 non-null    float64
#  4   Lower secondary completion rate: Male: % of relevant age group: 2015                                                             133 non-null    float64
#  5   Lower secondary completion rate: Female: % of relevant age group: 2015                                                           133 non-null    float64
#  6   Youth literacy rate: Male: % of ages 15-24: 2005-14                                                                              131 non-null    float64
#  7   Youth literacy rate: Female: % of ages 15-24: 2005-14                                                                            131 non-null    float64
#  8   Adult literacy rate: Male: % ages 15 and older: 2005-14                                                                          132 non-null    float64
#  9   Adult literacy rate: Female: % ages 15 and older: 2005-14                                                                        132 non-null    float64
#  10  Students at lowest proficiency on PISA: Mathematics: % of 15 year-olds: 2015                                                     65 non-null     float64
#  11  Students at lowest proficiency on PISA: Reading: % of 15 year-olds: 2015                                                         65 non-null     float64
#  12  Students at lowest proficiency on PISA: Science: % of 15 year-olds: 2015                                                         63 non-null     float64
#  13  Population: millions: 2016                                                                                                       165 non-null    float64
#  14  Surface area: sq. km thousands: 2016                                                                                             166 non-null    float64
#  15  Population density: people per sq. km: 2016                                                                                      164 non-null    float64
#  16  Gross national income, Atlas method: $ billions: 2016                                                                            157 non-null    float64
#  17  Gross national income per capita, Atlas method: $: 2016                                                                          157 non-null    float64
#  18  Purchasing power parity gross national income: $ billions: 2016                                                                  157 non-null    float64
#  19  per capita: $: 2016                                                                                                              157 non-null    float64
#  20  Gross domestic product: % growth : 2016                                                                                          159 non-null    float64
#  21  per capita: % growth: 2016                                                                                                       159 non-null    float64
#  22  Prevalence of smoking: Male: % of adults: 2015                                                                                   112 non-null    float64
#  23  Prevalence of smoking: Female: % of adults: 2015                                                                                 114 non-null    float64
#  24  Incidence of tuberculosis: per 100,000 people: 2015                                                                              164 non-null    float64
#  25  Prevalence of diabetes: % of population ages 20 to 79: 2015                                                                      165 non-null    float64
#  26  Incidence of HIV: Total: % of uninfected population ages 15-49: 2015                                                             95 non-null     float64
#  27  Prevalence of HIV: Total: % of population ages 15-49: 2015                                                                       94 non-null     float64
#  28  Prevalence of HIV: Women's share of population ages 15+ living with HIV: %: 2015                                                 94 non-null     float64
#  29  Prevalence of HIV: Youth, Male: % of population ages 15-24: 2015                                                                 94 non-null     float64
#  30  Prevalence of HIV: Youth, Female: % of population ages 15-24: 2015                                                               94 non-null     float64
#  31  Antiretroviral therapy coverage: % of people living with HIV: 2015                                                               91 non-null     float64
#  32  Cause of death: Communicable diseases and maternal, prenatal, and nutrition conditions: % of population: 2015                    157 non-null    float64
#  33  Cause of death: Non-communicable diseases: % of population: 2015                                                                 157 non-null    float64
#  34  Cause of death: Injuries: % of population: 2015                                                                                  157 non-null    float64
#  35  Access to an improved water source: % of population: 1990                                                                        147 non-null    float64
#  36  Access to an improved water source: % of population: 2015                                                                        157 non-null    float64
#  37  Access to improved sanitation facilities: % of population: 1990                                                                  142 non-null    float64
#  38  Access to improved sanitation facilities: % of population: 2015                                                                  158 non-null    float64
#  39  Child immunization rate: Measles: % of children ages 12-23 months: 2015                                                          164 non-null    float64
#  40  Child immunization rate: DTP3: % of children ages 12-23 months: 2015                                                             164 non-null    float64
#  41  Children with acute respiratory infection taken to health provider: % of children under age 5 with ARI: 2009-2016                84 non-null     float64
#  42  Children with diarrhea who received oral rehydration and continuous feeding: % of children under age 5 with diarrhea: 2009-2016  83 non-null     float64
#  43  Children sleeping under treated bed nets: % of children under age 5: 2009-2016                                                   43 non-null     float64
#  44  Children with fever receiving antimalarial drugs: % of children under age 5 with fever: 2009-2016                                52 non-null     float64
#  45  Tuberculosis: Treatment success rate: % of new cases: 2014                                                                       159 non-null    float64
#  46  Tuberculosis: Cases detection rate: % of new estimated cases: 2015                                                               162 non-null    float64
# dtypes: float64(45), object(2)
# memory usage: 61.1+ KB

# %%
# Code Here
wb['Continent'].value_counts()
# Out:
# Africa        47
# Europe        43
# Asia          34
# N. America    18
# Oceania       13
# S. America    11
# Name: Continent, dtype: int64

# %% [markdown]
# Now we will use the [Matplotlib](https://matplotlib.org/stable/api/index) and [Seaborn](https://seaborn.pydata.org/api.html) plotting libraries to create visualizations. First, let's generate a bar plot using the Matplotlib function `plt.bar`.

# %%
plt.bar(wb['Continent'].value_counts().index, wb['Continent'].value_counts())
# Out:
# <BarContainer object of 6 artists>

# %%
# Code Here

# %% [markdown]
# Note that we concluded our call to `plt.bar` with a semicolon (`;`). This suppresses any unnecessary output other than the plot. If we do not include a semicolon, the plot will still generate, however, we will see extraneous text as well:

# %%
plt.bar(wb['Continent'].value_counts().index, wb['Continent'].value_counts());

# %%
# Code Here
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# We also remember to set the axis labels and the title for the plot.

# %%
plt.bar(wb['Continent'].value_counts().index, wb['Continent'].value_counts())
plt.xlabel('Continent')
plt.ylabel('Count')
plt.title('Distribution of Countries across the Continents');

# %%
# Code Here

# %% [markdown]
# `pandas` native plotting:

# %%
wb['Continent'].value_counts().plot(kind='bar');

# %%
# Code Here

# %% [markdown]
# Equivalently, we could use the `countplot` method of the Seaborn library to create our bar plot.

# %%
import seaborn as sns
sns.countplot(data=wb, x="Continent" )
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='count'>

# %%
# Code Here

# %% [markdown]
# Above, we said that bar plots should only be used to visualize the distribution of a qualitative (categorical) variable. Why is that? Consider what happens when we try to use `sns.countplot` to visualize a quantitative variable, gross national income per capita.

# %%
 wb.iloc[[5,7],[16]]
# Out:
#    Gross national income, Atlas method: $ billions: 2016
# 5                                               28.2
# 7                                               10.4

# %%
# Code Here
sns.countplot(data=wb, x="Gross national income per capita, Atlas method: $: 2016");

# %% [markdown]
# What happened? A bar plot (either `plt.bar` or `sns.countplot`) will create a separate bar for *each* unique value of a variable. With a continuous variable, we may not have a finite number of possible values, which can lead to situations where we would need many, many bars to display each unique value.
#
# To visualize the distribution of a continuous variable, we use a different type of plot:
# * Histogram
# * Box plot
# * Violin plot

# %% [markdown]
# ## Box Plots and Violin Plots

# %% [markdown]
# Box plots and violin plots are two very similar kinds of visualizations. Both display the distribution of a variable using information about quartiles.
#
# In a box plot, the width of the box at any point does not encode meaning. In a violin plot, the width of the plot indicates the *density* of the distribution at each possible value.

# %%
sns.boxplot(data=wb, y="Gross national income per capita, Atlas method: $: 2016");

# %%
# Code Here, use boxplot

# %%
# Code Here, Use voilinplot
sns.violinplot(data=wb, y="Gross national income per capita, Atlas method: $: 2016");

# %% [markdown]
# A quartile represents a 25% portion of the data. We say that:
# * The first quartile (Q1) repesents the 25th percentile – 25% of the data lies below the first quartile
# * The second quartile (Q2) represents the 50th percentile, also known as the median – 50% of the data lies below the second quartile
# * The third quartile (Q3) represents the 75th percentile – 75% of the data lies below the third quartile.
#
# This means that the middle 50% of the data lies *between* the first and third quartiles. It would help if you encode quartiles (1st, 2nd, 3rd) information over histogram. This is demonstrated in the histogram below. The three quartiles are marked with red vertical bars.

# %%
# plot a histogram for 'Gross domestic product: % growth : 2016'
#Code Here
q1, q2, q3 =wb['Gross domestic product: % growth : 2016'].quantile([0.25, 0.5, 0.75])

# %%
catagory = ['In the middle 50%', 'Outside of the middle 50%']
ax = sns.histplot(wb, x= 'Gross domestic product: % growth : 2016', kde = False);
ax.axvline(q1, color='red', linestyle='-', linewidth=0.8, ymax=0.1, label = "Q1")
ax.axvline(q2, color='red', linestyle='-', linewidth=0.8, ymax=0.1, label ="Q2")
ax.axvline(q3, color='red', linestyle='-', linewidth=0.8, ymax=0.1, label ="Q3")
plt.legend(catagory)
plt.show()

# %%
# plot a histogram for 'Gross domestic product: % growth : 2016'
#Code Here

# %% [markdown]
# In a box plot, the lower extent of the box lies at Q1, while the upper extent of the box lies at Q3. The horizontal line in the middle of the box corresponds to Q2 (equivalently, the median).

# %%
# Code Here
q1 = wb['Gross domestic product: % growth : 2016'].quantile(0.25)
q2 = wb['Gross domestic product: % growth : 2016'].quantile(0.50)
q3 = wb['Gross domestic product: % growth : 2016'].quantile(0.75)

sns.boxplot(data=wb, y='Gross domestic product: % growth : 2016')
# Out:
# <AxesSubplot:ylabel='Gross domestic product: % growth : 2016'>

# %%
# Code Here

# %% [markdown]
# A violin plot display quartile information, albeit a bit more subtly. Look closely at the center vertical bar of the violin plot below!

# %%
# Code Here
q1 = wb['Gross domestic product: % growth : 2016'].quantile(0.25)
q2 = wb['Gross domestic product: % growth : 2016'].quantile(0.50)
q3 = wb['Gross domestic product: % growth : 2016'].quantile(0.75)

sns.violinplot(data=wb, y='Gross domestic product: % growth : 2016')
# Out:
# <AxesSubplot:ylabel='Gross domestic product: % growth : 2016'>

# %%
# Code Here

# %% [markdown]
# Plotting side-by-side box or violin plots allow us to compare distributions across different categories. In other words, they enable us to plot *both* a qualitative variable and a quantitative continuous variable in one visualization.
#
# Seaborn allows us to easily create side-by-side plots by specify both an `x` and `y` column.

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=wb, x='Continent', y='Gross domestic product: % growth : 2016')
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='Gross domestic product: % growth : 2016'>

# %%
# Code Here
